# %%
import os
import glob
import pandas as pd
import openpyxl

# %%
os.chdir('C:\\Users\\josel\\OneDrive - EAE Business School\\Documentos\\SIS International\\Concatenate')

# %%
file_extension = '.xlsx'
excel_files = [i for i in glob.glob(f"*{file_extension}")]

# %%
for excel in excel_files:
    out = excel.split('.')[0]+'.csv'
    df = pd.read_excel(excel) # if only the first sheet is needed
    df.to_csv(out)

# %%
# Out:
# These are all of the filenames ending in .csv ['DC Business Owners 2.xlsx', 'huge-company-owners-usa.xlsx'].

# %%
# Out:
#                                 Email Verify Status First Name  Last Name  \
# 0             CCadwell@fourcounty.org       unknown     Carrie    Cadwell
# 1             paul.schille@moovel.com     not valid       Paul    Schille
# 2           jared@briosolarenergy.com         valid      Jared      Fager
# 3             michael@gettyimages.com         valid    Michael    Bezjian
# 4        ramsey.nubani@norcalcann.com         valid     Ramsey     Nubani
# ...                               ...           ...        ...        ...
# 997          mccannfranklyn@gmail.com         valid   Franklyn     McCann
# 998            frank@usglobalteam.com         valid   Franklyn     McCann
# 999   keith.haney@regionalhyundai.com     not valid      Keith      Haney
# 1000      sheri@yourtherapysource.net         valid      Sheri    Yarbray
# 1001     eric@omghospitalitygroup.com         valid       Eric  Leitstein
#
#             Full Name                                        User Social  \
# 0      Carrie Cadwell  https://www.linkedin.com/in/carrie-cadwell-a73...
# 1        Paul Schille   https://www.linkedin.com/in/paul-schille-11682a7
# 2         Jared Fager   https://www.linkedin.com/in/jared-fager-43387172
# 3     Michael Bezjian         https://www.linkedin.com/in/michaelbezjian
# 4       Ramsey Nubani           https://www.linkedin.com/in/ramseynubani
# ...               ...                                                ...
# 997   Franklyn McCann  https://www.linkedin.com/in/franklyn-mccann-1b...
# 998   Franklyn McCann  https://www.linkedin.com/in/franklyn-mccann-1b...
# 999       Keith Haney   https://www.linkedin.com/in/keith-haney-58015033
# 1000    Sheri Yarbray               https://www.linkedin.com/in/ytsource
# 1001   Eric Leitstein          https://www.linkedin.com/in/ericleitstein
#
#                                                Position  \
# 0                                         President/CEO
# 1                            VP of Business Development
# 2                                                   NaN
# 3     Contributing photographer at Getty Images / Wi...
# 4                               Director of Cultivation
# ...                                                 ...
# 997                                                 NaN
# 998                                                 NaN
# 999                                       Owner/Partner
# 1000                                              Owner
# 1001                  Founder & Chief Executive Officer
#
#                 Prospect Locality             Add Date  \
# 0             Logansport. Indiana  2019-07-12 03:36:25
# 1           Portland. Oregon Area  2019-07-12 03:36:25
# 2              South Jordan. Utah  2019-07-12 03:36:25
# 3         Los Angeles. California  2019-07-12 03:36:25
# 4          San Francisco Bay Area  2019-07-12 03:36:25
# ...                           ...                  ...
# 997      New Port Richey. Florida  2019-07-12 02:10:30
# 998      New Port Richey. Florida  2019-07-12 02:10:30
# 999          Tulsa. Oklahoma Area  2019-07-12 02:10:30
# 1000  North Richland Hills. Texas  2019-07-12 02:10:30
# 1001       Greater San Diego Area  2019-07-12 02:10:30
#
#                        Company Name                         Company Url  \
# 0     Four County Counseling Center               http://fourcounty.org
# 1                      moovel Group               http://www.moovel.com
# 2                               NaN                                 NaN
# 3                      Getty Images          http://www.gettyimages.com
# 4                NorCal Cannabis Co           http://www.norcalcann.com
# ...                             ...                                 ...
# 997                             NaN                                 NaN
# 998                             NaN                                 NaN
# 999                Regional Hyundai      http://www.regionalhyundai.com
# 1000       Your Therapy Source. LLC              http://www.ytshome.com
# 1001          OMG Hospitality Group  http://www.omghospitalitygroup.com
#
#                                          Company Social Company Size  \
# 0              https://www.linkedin.com/company/1183663      201-500
# 1              https://www.linkedin.com/company/9300662      201-500
# 2                                                   NaN          NaN
# 3                 https://www.linkedin.com/company/4828    1001-5000
# 4             https://www.linkedin.com/company/18648590      201-500
# ...                                                 ...          ...
# 997                                                 NaN          NaN
# 998                                                 NaN          NaN
# 999   http://www.yelp.com/biz/regional-hyundai-broke...          NaN
# 1000           https://www.linkedin.com/company/2951630      201-500
# 1001           https://www.linkedin.com/company/7932619         1-10
#
#             Country                  Locality               State  \
# 0     United States             United States             Indiana
# 1           Germany                   Germany  Baden- Württemberg
# 2     United States        South Jordan. Utah                 NaN
# 3     United States             United States             Seattle
# 4     United States             United States          California
# ...             ...                       ...                 ...
# 997   United States  New Port Richey. Florida                 NaN
# 998   United States  New Port Richey. Florida                 NaN
# 999   United States              Broken Arrow                  OK
# 1000  United States             United States                  TX
# 1001  United States             United States                  Ca
#
#                       City                             Industry
# 0               Logansport                   Mental Health Care
# 1                Stuttgart  Information Technology and Services
# 2                      NaN            Marketing and Advertising
# 3                  Seattle                          Photography
# 4            San Francisco                       Consumer Goods
# ...                    ...                                  ...
# 997                    NaN            Marketing and Advertising
# 998                    NaN            Marketing and Advertising
# 999                    NaN                           Automotive
# 1000  North Richland Hills               Hospital & Health Care
# 1001             San Diego                          Hospitality
#
# [1002 rows x 18 columns]
